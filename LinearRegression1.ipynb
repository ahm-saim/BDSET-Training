# %%
# !pip install scikit-learn

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import  LinearRegression

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/home - Sheet1.csv')

# %%
df
# Out:
#    Area  price
# 0  3000   5000
# 1  2900   4900
# 2  2880   4990
# 3  2500   4500
# 4  2990   2970
# 5  2500   2680
# 6  2700   2890
# 7  3150   3500
# 8  3200   3200

# %%
df.head()
# Out:
#    Area  price
# 0  3000   5000
# 1  2900   4900
# 2  2880   4990
# 3  2500   4500
# 4  2990   2970

# %%
df.tail()
# Out:
#    Area  price
# 4  2990   2970
# 5  2500   2680
# 6  2700   2890
# 7  3150   3500
# 8  3200   3200

# %%
df.isnull()
# Out:
#     Area  price
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False
# 5  False  False
# 6  False  False
# 7  False  False
# 8  False  False

# %%
df.isnull().sum()
# Out:
# Area     0
# price    0
# dtype: int64

# %%
# df = df.drop(columns=['Date'])

# %%
df
# Out:
#    Area  price
# 0  3000   5000
# 1  2900   4900
# 2  2880   4990
# 3  2500   4500
# 4  2990   2970
# 5  2500   2680
# 6  2700   2890
# 7  3150   3500
# 8  3200   3200

# %%
plt.scatter(df['Area'], df['price'])
plt.xlabel('Area 1')
plt.ylabel('Price')
plt.title('Square Fit vs Price')
plt.show()

# %%
y = df['price']
x = df[['Area']]

# %%
x
# Out:
#    Area
# 0  3000
# 1  2900
# 2  2880
# 3  2500
# 4  2990
# 5  2500
# 6  2700
# 7  3150
# 8  3200

# %%
y
# Out:
# 0    5000
# 1    4900
# 2    4990
# 3    4500
# 4    2970
# 5    2680
# 6    2890
# 7    3500
# 8    3200
# Name: price, dtype: int64

# %%
# x = df.drop(columns=['Price'])
# y = df['Price']

# %%
x
# Out:
#    Area
# 0  3000
# 1  2900
# 2  2880
# 3  2500
# 4  2990
# 5  2500
# 6  2700
# 7  3150
# 8  3200

# %%
y
# Out:
# 0    5000
# 1    4900
# 2    4990
# 3    4500
# 4    2970
# 5    2680
# 6    2890
# 7    3500
# 8    3200
# Name: price, dtype: int64

# %%
reg = LinearRegression()

# %%
x.mean()
# Out:
# Area    2868.888889
# dtype: float64

# %%
y.mean()
# Out:
# np.float64(3847.777777777778)

# %%
plt.scatter(x.mean(), y.mean(),color='red')
plt.scatter(df['Area'], df['price'])
plt.xlabel('Square Fit')
plt.ylabel('Price')
plt.title('Square Fit vs Price')
plt.show()

# %%
reg.fit(x,y) #train the ml model
# Out:
# LinearRegression()

# %%
m = reg.coef_

# %%
c = reg.intercept_

# %%
#y = mx+c
m*3350+c
# Out:
# array([3967.4158618])

# %%
reg.predict([[3350]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3967.4158618])

# %%
reg.predict([[3650]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4042.01697656])

# %%
df['predicted_y'] = reg.predict(x)
df.head()
# Out:
#    Area  price  predicted_y
# 0  3000   5000  3880.381228
# 1  2900   4900  3855.514190
# 2  2880   4990  3850.540782
# 3  2500   4500  3756.046037
# 4  2990   2970  3877.894524

# %%
plt.plot(df['Area'], reg.predict(df[['Area']]))
plt.scatter(df['price'], df['price'])
